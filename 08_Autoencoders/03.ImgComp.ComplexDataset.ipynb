# %% [markdown]
# # Autoencoder for image compression - Complex datasets

# %% [markdown]
# ### Import Libraries and modules

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Input, Conv2D, MaxPooling2D, UpSampling2D, BatchNormalization, AveragePooling2D
from tensorflow.keras.datasets import cifar10

tf.__version__
# Out:
# '2.20.0'

# %% [markdown]
# ### Load dataset and preprocess the data
#
# Ref. Dataset: https://keras.io/api/datasets/cifar10/ and https://www.cs.toronto.edu/~kriz/cifar.html

# %%
(X_train, y_train), (X_test, y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 69s 0us/step

# %%
X_train.shape, y_train.shape
# Out:
# ((50000, 32, 32, 3), (50000, 1))

# %%
X_test.shape, y_test.shape
# Out:
# ((10000, 32, 32, 3), (10000, 1))

# %%
32 * 32
# Out:
# 1024

# %%
X_train[0]
# Out:
# array([[[ 59,  62,  63],
#         [ 43,  46,  45],
#         [ 50,  48,  43],
#         ...,
#         [158, 132, 108],
#         [152, 125, 102],
#         [148, 124, 103]],
#
#        [[ 16,  20,  20],
#         [  0,   0,   0],
#         [ 18,   8,   0],
#         ...,
#         [123,  88,  55],
#         [119,  83,  50],
#         [122,  87,  57]],
#
#        [[ 25,  24,  21],
#         [ 16,   7,   0],
#         [ 49,  27,   8],
#         ...,
#         [118,  84,  50],
#         [120,  84,  50],
#         [109,  73,  42]],
#
#        ...,
#
#        [[208, 170,  96],
#         [201, 153,  34],
#         [198, 161,  26],
#         ...,
#         [160, 133,  70],
#         [ 56,  31,   7],
#         [ 53,  34,  20]],
#
#        [[180, 139,  96],
#         [173, 123,  42],
#         [186, 144,  30],
#         ...,
#         [184, 148,  94],
#         [ 97,  62,  34],
#         [ 83,  53,  34]],
#
#        [[177, 144, 116],
#         [168, 129,  94],
#         [179, 142,  87],
#         ...,
#         [216, 184, 140],
#         [151, 118,  84],
#         [123,  92,  72]]], dtype=uint8)

# %%
y_train[0]
# Out:
# array([6], dtype=uint8)

# %% [markdown]
# ### Visualize the dataset / Images

# %%
width = 10
height = 10

fig, axes = plt.subplots(height, width, figsize = (15,15))
axes = axes.ravel()
for i in np.arange(0, width * height):
    index = np.random.randint(0, 50000)
    axes[i].imshow(X_train[index], cmap = 'gray' )
    axes[i].set_title(y_train[index], fontsize = 8)
    axes[i].axis('off')

plt.subplots_adjust(hspace=0.4);

# %% [markdown]
# ### Preprocessing Images

# %%
X_train = X_train / 255
X_test = X_test / 255

# %%
X_train.shape, X_test.shape
# Out:
# ((50000, 32, 32, 3), (10000, 32, 32, 3))

# %% [markdown]
# ### Build and train the linear autoencoder model

# %%
# BatchNormalization: https://keras.io/api/layers/normalization_layers/batch_normalization/

autoencoder = tf.keras.models.Sequential()

# Encoder
autoencoder.add(Conv2D(64, (3,3), activation = 'relu', padding='same', input_shape=(32, 32, 3)))
autoencoder.add(BatchNormalization())
autoencoder.add(AveragePooling2D((2,2), padding="same"))

autoencoder.add(Conv2D(32, (3,3), activation = 'relu', padding='same'))
autoencoder.add(BatchNormalization())
autoencoder.add(AveragePooling2D((2,2), padding="same"))

autoencoder.add(Conv2D(16, (3,3), activation = 'relu', padding="same"))
autoencoder.add(BatchNormalization())
autoencoder.add(AveragePooling2D((2,2), padding="same")) # Encoded image

# Decoder
autoencoder.add(Conv2D(16, (3,3), activation = 'relu', padding="same"))
autoencoder.add(BatchNormalization())
autoencoder.add(UpSampling2D((2, 2)))

autoencoder.add(Conv2D(32, (3,3), activation = 'relu', padding="same"))
autoencoder.add(BatchNormalization())
autoencoder.add(UpSampling2D((2, 2)))

autoencoder.add(Conv2D(64, (3,3), activation = 'relu', padding="same"))
autoencoder.add(BatchNormalization())
autoencoder.add(UpSampling2D((2, 2)))

autoencoder.add(Conv2D(3, (3,3), activation='sigmoid', padding="same"))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
autoencoder.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 32, 32, 64)     │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 32, 32, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ average_pooling2d               │ (None, 16, 16, 64)     │             0 │
# │ (AveragePooling2D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 16, 16, 32)     │        18,464 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 16, 16, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ average_pooling2d_1             │ (None, 8, 8, 32)       │             0 │
# │ (AveragePooling2D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 8, 8, 16)       │         4,624 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 8, 8, 16)       │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ average_pooling2d_2             │ (None, 4, 4, 16)       │             0 │
# │ (AveragePooling2D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 4, 4, 16)       │         2,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 4, 4, 16)       │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d (UpSampling2D)    │ (None, 8, 8, 16)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 8, 8, 32)       │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 8, 8, 32)       │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_1 (UpSampling2D)  │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 16, 16, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 16, 16, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_2 (UpSampling2D)  │ (None, 32, 32, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 32, 32, 3)      │         1,731 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 52,963 (206.89 KB)
#  Trainable params: 52,515 (205.14 KB)
#  Non-trainable params: 448 (1.75 KB)

# %%
# Output = (Input - Filter + 1) / Stride

# %%
autoencoder.compile(optimizer = 'Adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
history = autoencoder.fit(X_train, X_train, epochs = 50, batch_size = 256, validation_data = (X_test, X_test))
# autoencoder.fit(X_train, X_train, epochs = 50, batch_size = 256, validation_data = (X_test, X_test))
# Out:
# Epoch 1/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 23s 65ms/step - accuracy: 0.5473 - loss: 0.6033 - val_accuracy: 0.5020 - val_loss: 0.6561
# Epoch 2/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.6533 - loss: 0.5810 - val_accuracy: 0.5925 - val_loss: 0.6053
# Epoch 3/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.6897 - loss: 0.5758 - val_accuracy: 0.6983 - val_loss: 0.5766
# Epoch 4/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.7114 - loss: 0.5726 - val_accuracy: 0.7259 - val_loss: 0.5735
# Epoch 5/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.7237 - loss: 0.5698 - val_accuracy: 0.7194 - val_loss: 0.5708
# Epoch 6/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.7301 - loss: 0.5679 - val_accuracy: 0.7311 - val_loss: 0.5692
# Epoch 7/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.7379 - loss: 0.5663 - val_accuracy: 0.7380 - val_loss: 0.5676
# Epoch 8/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.7447 - loss: 0.5650 - val_accuracy: 0.7492 - val_loss: 0.5665
# Epoch 9/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.7489 - loss: 0.5644 - val_accuracy: 0.7478 - val_loss: 0.5668
# Epoch 10/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.7526 - loss: 0.5636 - val_accuracy: 0.7464 - val_loss: 0.5653
# Epoch 11/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.7555 - loss: 0.5630 - val_accuracy: 0.7659 - val_loss: 0.5636
# Epoch 12/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - accuracy: 0.7585 - loss: 0.5625 - val_accuracy: 0.7624 - val_loss: 0.5633
# Epoch 13/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.7625 - loss: 0.5621 - val_accuracy: 0.7469 - val_loss: 0.5637
# Epoch 14/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.7644 - loss: 0.5618 - val_accuracy: 0.7663 - val_loss: 0.5626
# Epoch 15/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.7681 - loss: 0.5613 - val_accuracy: 0.7607 - val_loss: 0.5621
# Epoch 16/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.7684 - loss: 0.5611 - val_accuracy: 0.7530 - val_loss: 0.5630
# Epoch 17/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.7693 - loss: 0.5608 - val_accuracy: 0.7572 - val_loss: 0.5616
# Epoch 18/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.7710 - loss: 0.5606 - val_accuracy: 0.7588 - val_loss: 0.5616
# Epoch 19/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.7707 - loss: 0.5604 - val_accuracy: 0.7708 - val_loss: 0.5612
# Epoch 20/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.7705 - loss: 0.5603 - val_accuracy: 0.7626 - val_loss: 0.5612
# Epoch 21/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.7734 - loss: 0.5601 - val_accuracy: 0.7692 - val_loss: 0.5627
# Epoch 22/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - accuracy: 0.7723 - loss: 0.5599 - val_accuracy: 0.7788 - val_loss: 0.5610
# Epoch 23/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.7730 - loss: 0.5598 - val_accuracy: 0.7862 - val_loss: 0.5609
# Epoch 24/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.7738 - loss: 0.5596 - val_accuracy: 0.7741 - val_loss: 0.5605
# Epoch 25/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.7744 - loss: 0.5595 - val_accuracy: 0.7808 - val_loss: 0.5610
# Epoch 26/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.7743 - loss: 0.5594 - val_accuracy: 0.7678 - val_loss: 0.5605
# Epoch 27/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.7750 - loss: 0.5593 - val_accuracy: 0.7813 - val_loss: 0.5598
# Epoch 28/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.7738 - loss: 0.5593 - val_accuracy: 0.7743 - val_loss: 0.5601
# Epoch 29/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.7759 - loss: 0.5591 - val_accuracy: 0.7730 - val_loss: 0.5630
# Epoch 30/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.7751 - loss: 0.5591 - val_accuracy: 0.7808 - val_loss: 0.5600
# Epoch 31/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.7759 - loss: 0.5590 - val_accuracy: 0.7772 - val_loss: 0.5606
# Epoch 32/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.7753 - loss: 0.5589 - val_accuracy: 0.7816 - val_loss: 0.5595
# Epoch 33/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.7767 - loss: 0.5588 - val_accuracy: 0.7738 - val_loss: 0.5610
# Epoch 34/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.7775 - loss: 0.5587 - val_accuracy: 0.7749 - val_loss: 0.5594
# Epoch 35/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.7782 - loss: 0.5587 - val_accuracy: 0.7772 - val_loss: 0.5596
# Epoch 36/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.7785 - loss: 0.5586 - val_accuracy: 0.7827 - val_loss: 0.5594
# Epoch 37/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.7789 - loss: 0.5585 - val_accuracy: 0.7808 - val_loss: 0.5608
# Epoch 38/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.7786 - loss: 0.5585 - val_accuracy: 0.7839 - val_loss: 0.5593
# Epoch 39/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.7797 - loss: 0.5585 - val_accuracy: 0.7841 - val_loss: 0.5596
# Epoch 40/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.7803 - loss: 0.5583 - val_accuracy: 0.7885 - val_loss: 0.5594
# Epoch 41/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.7804 - loss: 0.5583 - val_accuracy: 0.7858 - val_loss: 0.5593
# Epoch 42/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.7816 - loss: 0.5582 - val_accuracy: 0.7877 - val_loss: 0.5591
# Epoch 43/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.7817 - loss: 0.5582 - val_accuracy: 0.7846 - val_loss: 0.5594
# Epoch 44/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.7818 - loss: 0.5581 - val_accuracy: 0.7911 - val_loss: 0.5602
# Epoch 45/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - accuracy: 0.7820 - loss: 0.5581 - val_accuracy: 0.7834 - val_loss: 0.5587
# Epoch 46/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.7829 - loss: 0.5580 - val_accuracy: 0.7625 - val_loss: 0.5595
# Epoch 47/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - accuracy: 0.7832 - loss: 0.5580 - val_accuracy: 0.7831 - val_loss: 0.5588
# Epoch 48/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.7834 - loss: 0.5579 - val_accuracy: 0.7854 - val_loss: 0.5587
# Epoch 49/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.7841 - loss: 0.5578 - val_accuracy: 0.7813 - val_loss: 0.5590
# Epoch 50/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.7834 - loss: 0.5578 - val_accuracy: 0.7874 - val_loss: 0.5588

# %% [markdown]
# ### Encoding and Decoding Images using the trained autoencoder with test images

# %%
encoder = Model(inputs=autoencoder.layers[0].input, outputs = autoencoder.get_layer('average_pooling2d_2').output)
encoder.summary()
# Out:
# Model: "functional_19"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 32, 32, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 32, 32, 64)     │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 32, 32, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ average_pooling2d               │ (None, 16, 16, 64)     │             0 │
# │ (AveragePooling2D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 16, 16, 32)     │        18,464 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 16, 16, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ average_pooling2d_1             │ (None, 8, 8, 32)       │             0 │
# │ (AveragePooling2D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 8, 8, 16)       │         4,624 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 8, 8, 16)       │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ average_pooling2d_2             │ (None, 4, 4, 16)       │             0 │
# │ (AveragePooling2D)              │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 25,328 (98.94 KB)
#  Trainable params: 25,104 (98.06 KB)
#  Non-trainable params: 224 (896.00 B)

# %%
coded_test_images = encoder.predict(X_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step

# %%
coded_test_images.shape
# Out:
# (10000, 4, 4, 16)

# %%
coded_test_images[0]
# Out:
# array([[[-0.13972318, -0.11977434,  0.02260554, -0.34698528,
#           0.13400382,  0.13120526,  0.27259016, -0.11558044,
#           0.05528563,  0.12581906,  0.95197296,  0.29815036,
#           0.93096256,  0.8013229 ,  1.0520307 ,  0.5759267 ],
#         [ 0.00490302,  0.10656881, -0.09369373,  0.00599855,
#           0.37392527,  0.22124368,  0.2529931 ,  0.26114428,
#           0.33209813,  0.45591715,  0.99845415, -0.03693545,
#           0.69580126,  1.1043708 ,  0.95905656,  0.45632386],
#         [-0.1747554 ,  0.2848178 ,  0.19209689,  0.04951435,
#           0.23471653, -0.24127132,  0.5450034 , -0.21188557,
#          -0.21066523,  0.18805549,  0.5721441 ,  0.45282108,
#           0.6538245 ,  0.70370144,  0.825495  ,  0.07135355],
#         [-0.08381104,  0.18845463, -0.11049378, -0.39697897,
#           0.08499902, -0.0437316 ,  0.35118628, -0.32191634,
#           0.05735636, -0.06906387,  1.2626905 ,  0.27028054,
#           0.833148  ,  0.7895364 ,  0.5768765 ,  0.16504282]],
#
#        [[ 0.46598577,  0.32109988,  0.29427224,  0.03095973,
#          -0.01798487, -0.23829257,  0.04317904,  0.3678385 ,
#           0.30750525,  0.21797347,  0.81019354,  0.49771714,
#           0.8956463 ,  0.45994592,  0.65763783,  0.11043197],
#         [ 0.5316528 ,  0.10677272,  0.52781093,  0.01994532,
#           0.9746014 , -0.19272071, -0.07217968,  0.5003269 ,
#           0.07838011,  0.12848952,  0.3633009 ,  0.23360336,
#           0.45650083,  0.40874147,  1.1879551 , -0.4250068 ],
#         [-0.21164787,  0.1629864 ,  0.11767018, -0.15061891,
#           0.00869805, -0.38457114, -0.0107587 , -0.14330411,
#           0.23349309,  0.09557182,  0.57328475,  0.12549925,
#          -0.01022363,  0.24019325,  0.30361545, -0.17565632],
#         [-0.03583837,  0.00940758, -0.14913058,  0.0765391 ,
#           0.04651362, -0.12213749,  0.58164275, -0.5988329 ,
#          -0.30443066, -0.02582002,  0.5379046 ,  0.12407607,
#           0.6586478 ,  0.11522901,  0.19386953, -0.336901  ]],
#
#        [[-0.16382313,  0.4020244 ,  0.81274354,  0.67293614,
#           0.62402093, -0.37243068, -0.2573285 ,  0.2106309 ,
#           0.11812019,  0.03452411,  0.13314652,  0.40935588,
#           0.9063734 ,  0.05771822,  1.0816425 , -0.23668438],
#         [ 0.5970817 ,  0.06865674,  0.29876143, -0.39363283,
#           0.1389584 , -0.3998742 ,  0.10418639,  0.34399915,
#           0.33045346,  0.4455651 ,  0.5678399 ,  0.421996  ,
#           0.12249732, -0.09828115,  0.7626101 ,  0.12257075],
#         [ 0.27495247,  0.03255844,  0.1891188 ,  0.31780833,
#           0.42936468, -0.38640174,  0.41903168,  0.12547123,
#           0.16094011,  0.1220721 ,  1.0924037 ,  0.52016103,
#           0.49347878,  0.3771569 ,  0.05985624, -0.09783888],
#         [-0.003196  ,  0.29401875,  0.2987299 ,  0.07306319,
#          -0.07737893, -0.2839817 ,  0.49268317, -0.06108761,
#           0.10880899, -0.1680612 ,  0.9288545 ,  0.574905  ,
#           0.16102576,  0.5902964 ,  0.33278948, -0.00938958]],
#
#        [[ 0.11135846,  0.17593151,  0.43329275,  0.24812883,
#          -0.29209322, -0.4344574 ,  0.06212026, -0.08244455,
#          -0.27926877, -0.5822744 ,  0.6177503 ,  0.44398987,
#          -1.0272541 ,  0.16634446, -0.02314588, -0.13474739],
#         [-0.4284656 , -0.1591587 ,  0.6835616 ,  0.9446141 ,
#           0.20358491, -0.685368  ,  0.25377697, -0.4659419 ,
#          -0.14615124, -0.46364588,  1.0888692 ,  0.06180876,
#          -0.384341  ,  0.37258762, -0.39683455, -0.6476551 ],
#         [ 0.02760261,  0.30053067,  0.32263374,  0.54339075,
#           0.11114568, -0.49424097,  0.39453644, -0.44846678,
#          -0.18812138, -0.2581489 ,  0.59811234,  0.29391897,
#          -0.74166495,  0.16386592, -0.35217154, -0.8739503 ],
#         [-0.10706842,  0.08950651,  0.5894615 ,  0.7935757 ,
#          -0.11537969, -0.74509656,  0.18561369, -0.5206783 ,
#          -0.2935266 , -0.44693834,  0.37561905,  0.19597834,
#          -0.4797035 ,  0.06660253, -0.37648636, -0.8474922 ]]],
#       dtype=float32)

# %%
decoded_test_images = autoencoder.predict(X_test)
decoded_test_images.shape
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step
# (10000, 32, 32, 3)

# %%
n_images = 10
test_images = np.random.randint(0, X_test.shape[0], size = n_images)
plt.figure(figsize=(18,18))
for i, image_index in enumerate(test_images):
  
  # Original image
  ax = plt.subplot(10,10,i + 1)
  plt.imshow(X_test[image_index].reshape(32,32,3))
  plt.xticks(())
  plt.yticks(())
    
  # Coded image
  ax = plt.subplot(10,10,i + 1 + n_images)
  plt.imshow(coded_test_images[image_index].reshape(16,16))
  plt.xticks(())
  plt.yticks(())
    
  # Decoded image
  ax = plt.subplot(10,10,i + 1 + n_images * 2)
  plt.imshow(decoded_test_images[image_index].reshape(32,32,3))
  plt.xticks(())
  plt.yticks(())
